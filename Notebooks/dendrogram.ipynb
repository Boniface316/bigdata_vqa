# %%
from divisiveclustering.datautils import DataUtils
from divisiveclustering.plotsutils import plot_dendogram, plot_clustered_dendogram
from matplotlib import pyplot as plt

# %%
data_utils = DataUtils("/Users/yogi/libraries/Kmeans_NISQ/")

# %% [markdown]
# # Brute Force

# %%
BF_dendo_data = data_utils.load_dendo_data("BF")
plot_dendogram(BF_dendo_data)

# %%
BF_dendo_coloring_dict = data_utils.load_dendo_coloring_data("BF")
BF_cluster_color = data_utils.load_cluster_colors("BF")
plot_clustered_dendogram(BF_dendo_data, BF_dendo_coloring_dict, BF_cluster_color)
#plt.savefig("BF_dendo_k_4.png", facecolor='white', transparent=False)

# %% [markdown]
# # QAOA

# %%
QAOA_dendo_data = data_utils.load_dendo_data("QAOA")
plot_dendogram(QAOA_dendo_data)

# %%
QAOA_dendo_coloring_dict = data_utils.load_dendo_coloring_data("QAOA")
QAOA_cluster_color = data_utils.load_cluster_colors("QAOA")
plot_clustered_dendogram(QAOA_dendo_data, QAOA_dendo_coloring_dict, QAOA_cluster_color)
#plt.savefig("QAOA_dendo_k_4.png", facecolor='white', transparent=False)

# %% [markdown]
# # VQE

# %%
VQE_dendo_data = data_utils.load_dendo_data("VQE")
plot_dendogram(VQE_dendo_data)

# %%
VQE_dendo_coloring_dict = data_utils.load_dendo_coloring_data("VQE")
VQE_cluster_color = data_utils.load_cluster_colors("VQE")
plot_clustered_dendogram(VQE_dendo_data, VQE_dendo_coloring_dict, VQE_cluster_color)
#plt.savefig("VQE_dendo_k_4.png", facecolor='white', transparent=False)
